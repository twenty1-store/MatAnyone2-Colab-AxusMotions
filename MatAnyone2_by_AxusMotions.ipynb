# %%
# 1. Download the code
# !git clone https://github.com/pq-yang/MatAnyone2.git
# %cd MatAnyone2

# 2. Install the required tools
# !pip install -e .
# !pip install -r hugging_face/requirements.txt

# 3. Force the app to create a public web link so you can access it
# !sed -i 's/\.launch()/\.launch(share=True)/' hugging_face/app.py

# 4. Launch the Gradio Web UI
# %cd hugging_face
# !python app.py
